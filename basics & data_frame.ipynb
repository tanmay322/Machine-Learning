# %% [markdown]
# # This file contains basic Jupyter work flows, using pandas and dataframes

# %%
import pandas as pd

# %%
df = pd.read_csv("heart-disease.csv")

# %% [markdown]
# tHE FOLLOWING code shows top five records

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %% [markdown]
# This code below helps plot Bar graph for target attribute using data frame

# %%
df.target.value_counts().plot(kind="bar")

# %% [markdown]
# !.[_].(6-step-ml-framework.png)

# %% [markdown]
# ![title](6-step-ml-framework.png)

# %% [markdown]
# ## 1. Problem definition
# Predict Heart disease.

# %% [markdown]
# The image above is imported from files using the following format: ![<title>](<img_name>)

# %% [markdown]
# # 2. Data
# This is the data we are using
